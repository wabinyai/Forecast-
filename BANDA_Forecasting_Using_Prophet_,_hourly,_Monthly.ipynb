# %% [markdown]
# <a href="https://colab.research.google.com/github/wabinyai/Forecast-/blob/main/BANDA_Forecasting_Using_Prophet_%2C_hourly%2C_Monthly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet

from sklearn.metrics import mean_squared_error, mean_absolute_error

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid', {'axes.facecolor': '.9'})
sns.set_palette(palette='deep')
sns_c = sns.color_palette(palette='deep')
# %matplotlib inline

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():
  print ('Avacado dataset'.format(
      name=fn, length=len(uploaded[fn])
  ))
# Out:
#      <input type="file" id="files-3cacfc2d-729c-41a5-8fa4-2cf29960246d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cacfc2d-729c-41a5-8fa4-2cf29960246d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BandaHourlyPRO.csv to BandaHourlyPRO.csv
# Avacado dataset

# %%
df = pd.read_csv(fn, parse_dates=[0]) # We set the index column and know it has dates
df.head()
# Out:
#                    ds          y
# 0 2019-11-27 13:00:00  39.366842
# 1 2019-11-27 14:00:00  33.868718
# 2 2019-11-27 15:00:00  38.259744
# 3 2019-11-27 16:00:00  73.879048
# 4 2019-11-27 17:00:00  75.360000

# %% [markdown]
# # Hourly forecast

# %%
m = Prophet(changepoint_prior_scale=0.01).fit(df)
future = m.make_future_dataframe(periods=300, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)
plt.xticks(rotation=45)
plt.xlim('2021-12-12  00:00:00','2021-12-12  23:00:00')
plt.ylim(-12,120)
plt.legend()
plot = plt.suptitle('HOURLY FORE CAST')
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
m = Prophet(seasonality_mode='multiplicative').fit(df)
future = m.make_future_dataframe(periods=3652)
fcst = m.predict(future)
fig = m.plot(fcst)
plt.xlim('2021-12-12  00:00:00','2021-12-12  23:00:00')
# Out:
# (738136.0, 738136.9583333334)

# %%
 fig = m.plot_components(fcst)

# %%
m = Prophet(seasonality_mode='multiplicative').fit(df)
future = m.make_future_dataframe(periods=3652)
fcst = m.predict(future)
fig = m.plot(fcst)
plt.ylim(-12,120)
plt.xlim('2021-12-12  00:00:00','2022-12-12  23:00:00')
plt.legend()
plt.xticks(rotation=45)
plot = plt.suptitle('monthly FORE CAST')
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
